# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
link = "https://raw.githubusercontent.com/carsonbennett1/Hockey-Fantasy/refs/heads/main/stats.csv"

dataSet = pd.read_csv(link)
df = pd.DataFrame(dataSet)
df
# Out:
#                Name Position Team Nationality  Week1  Week2  Week3  Week4  \
# 0         C.McDavid        C  EDM         CAN   10.8   32.6   43.0    0.2
# 1       M.Scheifele        C  WPG         CAN   51.7   21.4    1.5   40.0
# 2         L.Raymond    LW/RW  DET         SWE   17.8   15.9   16.9   15.8
# 3          J.McCann     C/LW  SEA         CAN   16.2   47.4    6.8   15.2
# 4         Q.Byfield  C/LW/RW   LA         CAN   13.5    6.8    NaN    NaN
# 5          S.Jarvis     C/RW  CAR         CAN   -1.6   27.7   16.8   21.0
# 6   O.Ekman-Larsson        D  TOR         SWE   18.9   22.4    5.5   21.4
# 7            R.Josi        D  NSH         SWI   21.7   15.2   25.6   25.6
# 8          R.Dahlin        D  BUF         SWE   10.5   15.4   27.4   29.5
# 9     A.Pietrangelo        D  VGK         CAN   25.4    8.6   53.4   22.3
# 10     C.Hellebuyck        G  WPG         USA   62.6    7.4   28.6   22.0
# 11      U.Luukkonen        G  BUF         FIN    8.4   24.2   25.0    7.2
# ...

# %% [markdown]
# #### Fantasy Player Nationality at Week 6

# %%
#Get Pie Chart Labels
labels = ['Canadian', 'American', 'Finish', 'German', 'Swiss', 'Swedish']

# Get Player Nationalities
# Players must have played in Week6
canadian = df[(df['Nationality'] == 'CAN') & (~pd.isna(df['Week6']))]
american = df[(df['Nationality'] == 'USA') & (~pd.isna(df['Week6']))]
german = df[(df['Nationality'] == 'GER') & (~pd.isna(df['Week6']))]
swiss = df[(df['Nationality'] == 'SWI') & (~pd.isna(df['Week6']))]
finish = df[(df['Nationality'] == 'FIN') & (~pd.isna(df['Week6']))]
swedish = df[(df['Nationality'] == 'SWE') & (~pd.isna(df['Week6']))]

# Get Player Nationality Numbers
nums = [canadian['Name'].count(), american['Name'].count(), finish['Name'].count(), german['Name'].count(), 
        swiss['Name'].count(), swedish['Name'].count()]

# Show Distribution
plt.pie(nums, labels=labels, autopct='%1.1f%%', startangle=90,
    colors=['#f10707', '#004ec0', '#7daef7', '#ffd131', '#d90000', '#f1db00'])
plt.title("Player Nationality at Week 6")
plt.show()

# %% [markdown]
# #### C.McDavid Weekly Output (Fantasy Points)

# %%
mcdavid_df = df[df['Name'] == 'C.McDavid']
x = ['Week1', 'Week2', 'Week3', 'Week4', 'Week5', 'Week6', 'Week7', 'Week8',
     'Week9', 'Week10', 'Week11']
mcdavid = [mcdavid_df['Week1'], mcdavid_df['Week2'], mcdavid_df['Week3'], mcdavid_df['Week4'], 
     mcdavid_df['Week5'], mcdavid_df['Week6'], mcdavid_df['Week7'], mcdavid_df['Week8'],
     mcdavid_df['Week9'], mcdavid_df['Week10'], mcdavid_df['Week11']
    ]

plt.figure(figsize=(12,7))

plt.title("C.McDavid Weekly Output (Fantasy Points)")
plt.xlabel("Weeks")
plt.ylabel("Fantasy Week Total")

plt.plot(x,mcdavid)

plt.grid(color='green', linestyle='--', linewidth='0.5')

plt.show()

# %% [markdown]
# #### N.Hischier vs. B.Point (Fantasy Week Totals)

# %%
hischier_df = df[df['Name'] == 'N.Hischier']
point_df = df[df['Name'] == 'B.Point']


x = ['Week1', 'Week2', 'Week3', 'Week4', 'Week5', 'Week6', 'Week7', 'Week8',
     'Week9', 'Week10', 'Week11']


hischier = [hischier_df['Week1'], hischier_df['Week2'], hischier_df['Week3'], hischier_df['Week4'], 
     hischier_df['Week5'], hischier_df['Week6'], hischier_df['Week7'], hischier_df['Week8'],
     hischier_df['Week9'], hischier_df['Week10'], hischier_df['Week11']
    ]
point = [point_df['Week1'], point_df['Week2'], point_df['Week3'], point_df['Week4'], 
     point_df['Week5'], point_df['Week6'], point_df['Week7'], point_df['Week8'],
     point_df['Week9'], point_df['Week10'], point_df['Week11']
    ]

plt.figure(figsize=(12,7))

plt.title("N.Hischier vs. B.Point (Fantasy Week Totals)")
plt.xlabel("Weeks")
plt.ylabel("Fantasy Week Total")

plt.plot(x,hischier)
plt.plot(x,point)
plt.legend(["Hischier","Point"], loc="upper right")

plt.grid(color='green', linestyle='--', linewidth='0.5')

plt.show()

# %% [markdown]
# #### Centre Point Summary

# %%
mcdavid_arr = np.array([])
point_arr = np.array([])
hischier_arr = np.array([])

for i in range(0,len(mcdavid),1):
    mcdavid_arr = np.append(mcdavid_arr,mcdavid[i])
    point_arr = np.append(point_arr,point[i])
    hischier_arr = np.append(hischier_arr,hischier[i])

x = ['C.McDavid', 'B.Point', 'N.Hischier']
y = [np.sum(mcdavid_arr), np.sum(point_arr), np.sum(hischier_arr)]

bar_graph = plt.bar(x,y)
bar_graph[0].set_color('orange')
bar_graph[1].set_color('blue')
bar_graph[2].set_color('red')

plt.title('Centre Point Totals')
plt.ylabel('Total Fantasy Points')
plt.xlabel('Centremen')
plt.grid(axis = 'y')
plt.show()
